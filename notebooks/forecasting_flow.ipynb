# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("postgresql+psycopg2://postgres:postgres@localhost:5432/iahVision")
def get_ipm_data_factor(engine):
    tabel_faktor = ['ipm', 'ahh', 'ahs', 'rls', 'ppk']
    df_dict = {}

    for faktor in tabel_faktor:
        query = f"""
            SELECT  
                p.provinsi, 
                f.* 
            FROM provinsi p
            JOIN {faktor} f ON p.id_provinsi = f.id_provinsi
        """
        df = pd.read_sql(query, engine)

        # rename columns
        renamed_columns = {}
        for col in df.columns:
            if f"{faktor}_" in col:
                renamed_columns[col] = col.replace(f"{faktor}_", "")
        
        df.rename(columns=renamed_columns, inplace=True)
        df_dict[faktor] = df

        print(f"Mendapatakan data {faktor}. Shape: {df.shape}")

    return df_dict

df_dict = get_ipm_data_factor(engine)
# Out:
# Mendapatakan data ipm. Shape: (34, 18)
# Mendapatakan data ahh. Shape: (34, 18)
# Mendapatakan data ahs. Shape: (34, 18)
# Mendapatakan data rls. Shape: (34, 18)
# Mendapatakan data ppk. Shape: (34, 18)

# %%
df_dict['ipm']
# Out:
#                 provinsi  id_ipm  id_provinsi   2010   2011   2012   2013  \
# 0                   ACEH  IPM001            1  67.09  67.45  67.81  68.30
# 1         SUMATERA UTARA  IPM002            2  67.09  67.34  67.74  68.36
# 2         SUMATERA BARAT  IPM003            3  67.25  67.81  68.36  68.91
# 3                   RIAU  IPM004            4  68.65  68.90  69.15  69.91
# 4                  JAMBI  IPM005            5  65.39  66.14  66.94  67.76
# 5       SUMATERA SELATAN  IPM006            6  64.44  65.12  65.79  66.16
# 6               BENGKULU  IPM007            7  65.35  65.96  66.61  67.50
# 7                LAMPUNG  IPM008            8  63.71  64.20  64.87  65.73
# 8   KEP. BANGKA BELITUNG  IPM009            9  66.02  66.59  67.21  67.92
# 9              KEP. RIAU  IPM010           10  71.13  71.61  72.36  73.02
# 10           DKI JAKARTA  IPM011           11  76.31  76.98  77.53  78.08
# 11            JAWA BARAT  IPM012           12  66.15  66.67  67.32  68.25
# 12           JAWA TENGAH  IPM013           13  66.08  66.64  67.21  68.02
# 13         DI YOGYAKARTA  IPM014           14  75.37  75.93  76.15  76.44
# 14            JAWA TIMUR  IPM015           15  65.36  66.06  66.74  67.55
# 15                BANTEN  IPM016           16  67.54  68.22  68.92  69.47
# 16                  BALI  IPM017           17  70.10  70.87  71.62  72.09
# 17   NUSA TENGGARA BARAT  IPM018           18  61.16  62.14  62.98  63.76
# 18   NUSA TENGGARA TIMUR  IPM019           19  59.21  60.24  60.81  61.68
# 19      KALIMANTAN BARAT  IPM020           20  61.97  62.35  63.41  64.30
# 20     KALIMANTAN TENGAH  IPM021           21  65.96  66.38  66.66  67.41
# 21    KALIMANTAN SELATAN  IPM022           22  65.20  65.89  66.68  67.17
# 22      KALIMANTAN TIMUR  IPM023           23  71.31  72.02  72.62  73.21
# 23        SULAWESI UTARA  IPM024           24  67.83  68.31  69.04  69.49
# 24       SULAWESI TENGAH  IPM025           25  63.29  64.27  65.00  65.79
# 25      SULAWESI SELATAN  IPM026           26  66.00  66.65  67.26  67.92
# 26     SULAWESI TENGGARA  IPM027           27  65.99  66.52  67.07  67.55
# 27             GORONTALO  IPM028           28  62.65  63.48  64.16  64.70
# 30  65.18  65.91  66.63  67.20  67.76  68.70  68.49  68.76  69.47  70.21
# 31  61.28  61.73  62.21  62.99  63.74  64.70  65.09  65.26  65.16  66.16
# 32  56.75  57.25  58.05  59.09  60.06  60.84  60.44  60.62  71.76  72.41
# 33  68.90  69.55  70.18  70.81  71.39  71.92  71.94  72.29  72.91  73.55
#
#      2024
# 0   74.03
# 1   74.02
# 2   74.49
# 3   74.79
# 4   73.43
# 5   72.30
# 6   73.39
# 7   71.81
# 8   73.33
# 9   77.97
# 10  83.08
# 11  74.43
# 12  73.88
# 13  81.55
# 14  74.09
# 15  74.48
# 16  77.76
# 17  70.93
# 18  67.39
# 19  70.13
# 20  72.73
# 21  73.03
# 22  78.83
# 23  75.03
# 24  71.56
# 25  74.05
# 26  73.48
# 27  71.23
# 28  68.20
# 29  71.57
# 30  71.03
# 31  67.02
# 32  73.00
# 33  74.20

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import mlflow
from darts import TimeSeries
from darts.metrics import mape
from darts.models import Theta, Prophet, LinearRegressionModel, NaiveDrift, NaiveSeasonal

def get_ipm_data_factor(engine, factor):
    query = f"""
        SELECT p.provinsi, f.*
        FROM provinsi p
        JOIN {factor} f ON p.id_provinsi = f.id_provinsi
    """
    df = pd.read_sql(query, engine)
    renamed = {col: col.replace(f"{factor}_", "") for col in df.columns if col.startswith(f"{factor}_")}
    df.rename(columns=renamed, inplace=True)
    print(f"Loaded {factor} data with shape {df.shape}")
    return df

def forecasting_with_mlflow(df, id_col, factor_name, start_year=2010, end_year=2024, predict_years=2):
    years = [str(y) for y in range(start_year, end_year+1)]
    time_index = pd.date_range(str(start_year), periods=len(years), freq="Y")

    models = [
        Theta(),
        Prophet(),
        LinearRegressionModel(lags=4),
        NaiveDrift(),
        NaiveSeasonal(K=12)
    ]

    mlflow.set_experiment(f"Forecasting_{factor_name.upper()}")

    results = []
    for idx, row in df.iterrows():
        prov_id = row[id_col]
        values = row[years].values.astype(float)

        ts = TimeSeries.from_times_and_values(time_index, values)
        train, val = ts[:-predict_years], ts[-predict_years:]

        best_model, best_mape, best_model_name = None, float('inf'), None

        for model in models:
            name = model.__class__.__name__
            try:
                model.fit(train)
                pred = model.predict(len(val))
                score = mape(val, pred)
                if score < best_mape:
                    best_mape = score
                    best_model = model
                    best_model_name = name
            except Exception as e:
                print(f"Error {name} at prov {prov_id}: {e}")

        future_pred = best_model.predict(predict_years).values().flatten() if best_model else [np.nan]*predict_years

        with mlflow.start_run(run_name=f"{factor_name}_{prov_id}"):
            mlflow.set_tag("prov_id", prov_id)
            mlflow.set_tag("factor", factor_name)
            mlflow.log_param("best_model", best_model_name)
            mlflow.log_metric("mape", best_mape)

        results.append({
            id_col: prov_id,
            "best_model": best_model_name,
            "mape_validasi": best_mape,
            **{str(end_year+i+1): future_pred[i] for i in range(predict_years)}
        })

    df_pred = pd.DataFrame(results)
    df_final = df.merge(df_pred, on=id_col, how="left")

    all_years = [str(y) for y in range(start_year, end_year + 1 + predict_years)]
    df_final[all_years] = df_final[all_years].astype(float)

    return df_final

# %%
list_factors = ['ipm', 'ahh', 'ahs', 'rls', 'ppk']
all_results = []

for factor in list_factors:
    df_factor = get_ipm_data_factor(engine, factor)
    df_result = forecasting_with_mlflow(df_factor, id_col="provinsi", factor_name=factor)
    all_results.append(df_result)
# Out:
# Loaded ipm data with shape (34, 18)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 6
#       4 for factor in list_factors:
#       5     df_factor = get_ipm_data_factor(engine, factor)
# ----> 6     df_result = forecasting_with_mlflow(df_factor, id_col="provinsi", factor_name=factor)
#       7     all_results.append(df_result)
#
# Cell In[6], line 33, in forecasting_with_mlflow(df, id_col, factor_name, start_year, end_year, predict_years)
#      23 time_index = pd.date_range(str(start_year), periods=len(years), freq="Y")
#      25 models = [
#      26     Theta(),
#      27     Prophet(),
#    (...)
#      30     NaiveSeasonal(K=12)
#      31 ]
# ---> 33 mlflow.set_experiment(f"Forecasting_{factor_name.upper()}")
#      35 results = []
#      36 for idx, row in df.iterrows():
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\tracking\fluent.py:157, in set_experiment(experiment_name, experiment_id)
#     155 with _experiment_lock:
#     156     if experiment_id is None:
# --> 157         experiment = client.get_experiment_by_name(experiment_name)
#     158         if not experiment:
#     159             try:
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\tracking\client.py:1703, in MlflowClient.get_experiment_by_name(self, name)
#    1671 def get_experiment_by_name(self, name: str) -> Optional[Experiment]:
#    1672     """Retrieve an experiment by experiment name from the backend store
#    1673
#    1674     Args:
#    (...)
#    1701         Lifecycle_stage: active
#    1702     """
# -> 1703     return self._tracking_client.get_experiment_by_name(name)
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:591, in TrackingServiceClient.get_experiment_by_name(self, name)
#     583 def get_experiment_by_name(self, name):
#     584     """
#     585     Args:
#     586         name: The experiment name.
#    (...)
#     589         :py:class:`mlflow.entities.Experiment`
#     590     """
# --> 591     return self.store.get_experiment_by_name(name)
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\store\tracking\file_store.py:355, in FileStore.get_experiment_by_name(self, experiment_name)
#     347 def pagination_wrapper_func(number_to_get, next_page_token):
#     348     return self.search_experiments(
#     349         view_type=ViewType.ALL,
#     350         max_results=number_to_get,
#     351         filter_string=f"name = '{experiment_name}'",
#     352         page_token=next_page_token,
#     353     )
# --> 355 experiments = get_results_from_paginated_fn(
#     356     paginated_fn=pagination_wrapper_func,
#     357     max_results_per_page=SEARCH_MAX_RESULTS_THRESHOLD,
#     358     max_results=None,
#     359 )
#     360 return experiments[0] if len(experiments) > 0 else None
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\utils\__init__.py:237, in get_results_from_paginated_fn(paginated_fn, max_results_per_page, max_results)
#     235     page_results = paginated_fn(num_to_get, next_page_token)
#     236 else:
# --> 237     page_results = paginated_fn(max_results_per_page, next_page_token)
#     238 all_results.extend(page_results)
#     239 if hasattr(page_results, "token") and page_results.token:
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\store\tracking\file_store.py:348, in FileStore.get_experiment_by_name.<locals>.pagination_wrapper_func(number_to_get, next_page_token)
#     347 def pagination_wrapper_func(number_to_get, next_page_token):
# --> 348     return self.search_experiments(
#     349         view_type=ViewType.ALL,
#     350         max_results=number_to_get,
#     351         filter_string=f"name = '{experiment_name}'",
#     352         page_token=next_page_token,
#     353     )
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\store\tracking\file_store.py:318, in FileStore.search_experiments(self, view_type, max_results, filter_string, order_by, page_token)
#     311 if max_results > SEARCH_MAX_RESULTS_THRESHOLD:
#     312     raise MlflowException(
#     313         f"Invalid value {max_results} for parameter 'max_results' supplied. It must be at "
#     314         f"most {SEARCH_MAX_RESULTS_THRESHOLD}",
#     315         INVALID_PARAMETER_VALUE,
#     316     )
# --> 318 self._check_root_dir()
#     319 experiment_ids = []
#     320 if view_type == ViewType.ACTIVE_ONLY or view_type == ViewType.ALL:
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\store\tracking\file_store.py:212, in FileStore._check_root_dir(self)
#     208 """
#     209 Run checks before running directory operations.
#     210 """
#     211 if not exists(self.root_directory):
# --> 212     raise Exception(f"'{self.root_directory}' does not exist.")
#     213 if not is_directory(self.root_directory):
#     214     raise Exception(f"'{self.root_directory}' is not a directory.")
#
# Exception: 'notebooks\mlruns' does not exist.
